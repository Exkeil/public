# %% [markdown]
# ## Практическая работа

# %% [markdown]
# В этой практической работе пять обязательных задач.
#
# *Обязательные задачи* помогут проверить, что вы действительно усвоили материал модуля. Сдайте их на проверку.
#
# Удачи!

# %% [markdown]
# Цели практической работы:
#
#
# 1.   Потренироваться в обучении модели линейной регрессии.
# 2.   Потренироваться в обучении модели логистической регрессии.
# 3.   Потренироваться в обучении модели многослойного персептрона.

# %% [markdown]
# Что оценивается:
#
# *   Все пункты и критерии приёмки по каждому заданию выполнены.
# *   Код оформлен и работает корректно.

# %% [markdown]
# Как отправить работу на проверку:
#
# Сдайте практическую работу этого модуля через систему контроля версий Git сервиса Skillbox GitLab. После загрузки работы на проверку напишите об этом в личном кабинете своему куратору.

# %% [markdown]
# В этом задании вам нужно построить модель классификации, определяющую категорию цены/цену подержанного автомобиля в зависимости от характеристик транспортного средства.
#
# Мы будем использовать датасет из коллекции подержанных автомобилей, выставленных на продажу в Соединенных Штатах. Он уже подготовлен, без выбросов и с категориальными фичами, преобразованными с помощью one hot encoding, и количественными фичами, стандартизированными с помощью скейлеров.

# %% [markdown]
# ### Описание датасета:
# - `id`: идентификатор записи;
# - `is_manufacturer_name`: признак производителя автомобиля;
#
# - `region_*`: регион;
# - `x0_*`: тип топлива;
# - `manufacturer_*`: производитель;
# - `short_model_*`: сокращённая модель автомобиля;
# - `title_status_*`: статус;
# - `transmission_*`: коробка передач;
# - `state_*`: штат;
# - `age_category_*`: возрастная категория автомобиля;
#
# - `std_scaled_odometer`: количество пройденных миль (после стандартизации);
# - `year_std`: год выпуска (после стандартизации);
# - `lat_std`: широта (после стандартизации);
# - `long_std`: долгота (после стандартизации);
# - `odometer/price_std`: отношение стоимости к пробегу автомобиля (после стандартизации);
# - `desc_len_std`: количество символов в тексте объявления о продаже (после стандартизации);
# - `model_in_desc_std`: количество наименований модели автомобиля в тексте объявления о продаже (после стандартизации);
# - `model_len_std`: длина наименования автомобиля (после стандартизации);
# - `model_word_count_std`: количество слов в наименовании автомобиля (после стандартизации);
# - `month_std`: номер месяца размещения объявления о продаже автомобиля (после стандартизации);
# - `dayofweek_std`: день недели размещения объявления о продаже автомобиля (после стандартизации);
# - `diff_years_std`: количество лет между годом производства автомобиля и годом размещения объявления о продаже автомобиля (после стандартизации);
#
# - `price`: стоимость;
# - `price_category`: категория цены.

# %% [markdown]
# ## Обязательные задачи

# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, mean_absolute_error
from sklearn.model_selection import train_test_split 
from sklearn.neural_network import MLPClassifier

# %%
df = pd.read_csv('vehicles_dataset_prepared.csv')
df.head()
# Out:
#            id  price price_category  is_audi  is_ford  is_chevrolet  \
# 0  7308295377  54990           high        0        0             0
# 1  7316380095  16942         medium        0        1             0
# 2  7313733749  35590           high        0        0             0
# 3  7308210929  14500         medium        0        0             0
# 4  7303797340  14590         medium        0        0             0
#
#    is_toyota  x0_diesel  x0_electric  x0_gas  ...  long_std  year_std  \
# 0          0        1.0          0.0     0.0  ...  0.484245  1.322394
# 1          0        0.0          0.0     0.0  ...  1.110800  0.695973
# 2          0        0.0          0.0     1.0  ...  0.531185  0.852578
# 3          1        0.0          0.0     1.0  ...  0.853562  0.226157
# 4          0        0.0          0.0     0.0  ...  0.557607  0.069552
#
#    odometer/price_std  desc_len_std  model_in_desc_std  model_len_std  \
# 0           -0.510784      0.632075          -0.155788       1.163032
# 1           -0.402947     -0.646781          -0.155788       0.932087
# 2           -0.514480      0.560744          -0.155788       0.470197
# 3           -0.241883      0.180435          -0.155788      -0.915473
# 4           -0.333074      0.766366          -0.155788       1.163032
#
#    model_word_count_std  month_std  dayofweek_std  diff_years_std
# 0              1.910669  -0.615846       1.120284       -1.322394
# 1              1.235799   1.623784      -1.374972       -0.695973
# 2              0.560930  -0.615846      -0.376870       -0.852578
# 3             -0.788810  -0.615846       1.120284       -0.226157
# 4              1.910669  -0.615846       0.122182       -0.069552
#
# [5 rows x 1463 columns]

# %% [markdown]
# **Задача 0. Линейная регрессия**
#
# Вспомните задачу по предсказанию стоимости поддержанного автомобиля. Попробуем обучить модель линейной регрессии для предсказания цены автомобиля (колонка `price`). Для этого проделайте следующие шаги:
#
# - Подготовьте данные: удалите колонки, которые косвенно содержат информацию о целевой переменной (`odometer/price_std`, `price_category`).
# - Разделите выборку на треин и тест в отношении 70/30.
# - Обучите модель линейной регрессии с дефолтными параметрами.
# - Посчитайте значение метрики mae на тестовой выборке для линейной регрессии.
# - Выведите получившиеся коэффициенты линейной регрессии при каждом параметре обучающей выборки с помощью метода `coef_`. Есть ли коэффициенты, которые равны нулю? Если есть, выведите названия фичей с нулевым коэффициентом
# - Удалите фичи, коэффициенты которых равны нулю. И переобучите модель. Убедитесь, что значение метрики не изменилось.

# %%
import numpy as np
df_prepared = df.drop(columns=['odometer/price_std', 'price_category'])

X = df_prepared.drop(columns=['price'])
y = df_prepared['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


feature_names = X_train.columns

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred_train = model.predict(X_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
print(f"MAE на обучающей выборке: {mae_train}")

y_pred_test = model.predict(X_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
print(f"MAE на тестовой выборке: {mae_test}")

coefficients = model.coef_

print('\nКоэффициенты линейной регрессии:')
for feature, coef in zip(feature_names, coefficients):
    print(f'{feature}: {coef}')


zero_coef_features = feature_names[np.isclose(coefficients, 0)]
print('\nФичи с нулевыми коэффициентами:')
print(zero_coef_features)

X_train_filtered = X_train.drop(columns=zero_coef_features)
X_test_filtered = X_test.drop(columns=zero_coef_features)

model_filtered = LinearRegression()
model_filtered.fit(X_train_filtered, y_train)

y_pred_filtered = model_filtered.predict(X_test_filtered)
mae_filtered = mean_absolute_error(y_test, y_pred_filtered)
print(f'\nMAE после удаления фичей с нулевыми коэффициентами: {mae_filtered}')
#значение метрики в этот раз не изменились, вернул 'id'
# Out:
# MAE на обучающей выборке: 3473.4842360694606
# MAE на тестовой выборке: 4600.341119684605
#
# Коэффициенты линейной регрессии:
# id: 6.3595102883915654e-06
# is_audi: 254.30385694452661
# is_ford: 1073.9083955930032
# is_chevrolet: -184.76392251792026
# is_toyota: 471.49883620737023
# x0_diesel: 5848.60657899518
# x0_electric: -2828.870374491994
# x0_gas: -1494.5886384370556
# x0_hybrid: -780.5406949313794
# x0_other: -744.608038885143
# std_scaled_odometer: -3529.6567495904283
# short_model_-benz: -5706.119238911191
# short_model_1: -7089.73739482708
# short_model_124: 0.0014211719444574555
# short_model_128i: -8435.624514343437
# short_model_135i: -4437.962284571656
# short_model_1500: -499.6193578261081
# short_model_163869: 301.88402985902985
# short_model_1928: 0.0004215836420371488
# short_model_1951: 11515.895244384688
# short_model_1954: 2447.6970245578395
# short_model_1960s: -3561.6813550231122
# short_model_1966: 41204.78817125912
# short_model_1968: 22801.394204019947
# short_model_1972: 11668.666034635375
# short_model_1977: 0.00042631603128029383
# short_model_1978: 6010.053337598641
# short_model_198.5: 11293.535393747334
# short_model_1988: -1178.419930770607
# short_model_1994: -5158.609767681002
# short_model_1999: -0.0002683491798052273
# short_model_2: -3652.4238609309673
# short_model_200: -2946.9345405823296
# short_model_2000: -0.0002549702958276612
# short_model_2002: 6654.178689210135
# short_model_2006: 0.00015867712136241607
# short_model_2007: -3383.6749905504776
# short_model_2008: -4260.465391222147
# short_model_2009: -2360.734573930575
# short_model_2012: 14411.895699765144
# short_model_2015: 0.0001066036584234098
# short_model_2016: -7.307967671010829e-05
# short_model_2017: 23933.048477582466
# short_model_2018: 14103.219528524629
# short_model_210: -5.6824341299943626e-05
# short_model_240: 3137.0970616979494
# short_model_2500: 4787.373022889116
# short_model_2500hd: -4.487241085371352e-05
# short_model_280zx: 5636.7891416289895
# short_model_3: -4523.932991889344
# short_model_3-series: -3587.7254506036716
# short_model_3-window: -0.00022301844518324287
# short_model_3.2: -2647.166440289635
# short_model_300: 2184.335209209651
# short_model_300-series: 3926.4771550883415
# short_model_300c: 4440.293869213229
# short_model_300s: 5893.805535401049
# short_model_300zx: 5903.034814537701
# short_model_3100: 16380.774716454862
# short_model_318i: 3845.8696743101546
# short_model_320i: -9248.546280629018
# short_model_323i: 7.493753491871757e-05
# short_model_325ci: -4058.443740888261
# short_model_325i: -4779.510574249235
# short_model_325is: 26479.159877533897
# short_model_325xi: -4442.372304349149
# short_model_328: -5259.179993981774
# short_model_328ci: -5.263339267003175e-05
# short_model_328d: -17957.78610631085
# short_model_328i: -8989.65972242734
# short_model_328xi: -8492.476585828643
# short_model_330i: -3077.1093852017393
# short_model_330xi: -7671.093917991016
# short_model_335i: -15918.041060469675
# short_model_335xi: -6624.882903836994
# short_model_350: -3898.8414568465632
# short_model_3500: 6083.919163666716
# short_model_3500hd: 4143.826377682446
# short_model_350z: -6531.810080624126
# short_model_370z: 4123.029160920142
# short_model_380sl: 14840.969358216264
# short_model_3i: -5100.617715480236
# short_model_4: -836.772737715351
# short_model_4-runner: 21633.001366536926
# short_model_428: -574.9012750020659
# short_model_430i: 920.9553902209475
# short_model_435i: -6594.707699708372
# short_model_440xi: -2.8168120479676872e-05
# short_model_4500: 12740.73552724098
# short_model_4runner: 4676.260577158957
# short_model_4x4: 21276.07056535981
# short_model_5: -5371.613322825749
# short_model_5-series: -9766.265483064062
# short_model_50: 2.954950878120144e-05
# short_model_500: -3984.419408334507
# short_model_500c: 3017.2539993568666
# short_model_500l: -8059.829691707858
# short_model_500x: 0.00030282875377452
# short_model_525i: -3.906247108886873e-05
# short_model_528i: -6191.471359670387
# short_model_528xi: -7515.351167415031
# short_model_530: -7223.251015473933
# short_model_530i: -0.00021862550465812092
# short_model_535i: -6139.836530216497
# short_model_535xi: 0.0002245803607365815
# short_model_540i: -1582.7575003948375
# short_model_545i: -0.000207694105277767
# short_model_5500: 14675.436137912371
# short_model_5500hd: 3593.356049872634
# short_model_550i: -8763.747348744817
# short_model_5th: 12099.89033681894
# short_model_6: 8562.97601252405
# short_model_640: 8.627511670056265e-05
# short_model_645ci: -1819.0633144889384
# short_model_650i: -4790.305847946008
# short_model_650xi: 5.460953786950995e-06
# short_model_7: 1129.7739069024333
# short_model_750: -3552.745579626763
# short_model_750i: -0.00018740354789770208
# short_model_750xi: -367.8104647353599
# short_model_86: -3239.4282249277567
# short_model_911: -3333.33362296977
# short_model_914: -19629.444378019256
# short_model_928: -6666.653311413057
# short_model_944: 0.00011956976413785014
# short_model_ACURA*: -2207.164966161666
# short_model_ALL: -22482.050631709022
# short_model_AM: 11246.200813991803
# short_model_AMC: 4268.163852590042
# short_model_ASC: 9266.418846709468
# short_model_Acuarea: 0.00019678839635162149
# short_model_American: 1289.8780568103507
# short_model_BUY: -24883.652641065088
# short_model_Bentley: -0.000305360264974297
# short_model_Blue: 9285.351854057537
# short_model_Buicks: -506.2990953420251
# short_model_C: -655.0354409646759
# short_model_CHEVORLET: -10010.932771663593
# short_model_CLICK: -29098.237216665806
# short_model_Champion: -0.0001947102773556253
# short_model_Chevey: -12671.618110877918
# short_model_Chevorlet: 34627.88375779958
# short_model_Comanche: 6254.395481249645
# short_model_Comet: -2919.728622685997
# short_model_D7FH173552: 26818.677517751552
# short_model_DODGE1500: 4412.1253169504835
# short_model_Diahatsu: -1728.5786790973746
# short_model_E46: -2381.4337651096903
# short_model_EASY: -5049.726085931093
# short_model_Eagle: 2335.6022266949935
# short_model_Emergency: 8483.911525916117
# short_model_F-250: 413.85403379098676
# short_model_F250: 3665.801041442047
# short_model_FORD*: -7.674643620703137e-05
# short_model_FORD/RANGER: -3549.957888513045
# short_model_FREIGHTLINER: 7870.617241692583
# short_model_FRRV: -14856.240796512519
# short_model_Flexible: -29838.589197180096
# short_model_FordE350: 2.036175283137709e-05
# short_model_Freightliner: 14657.131389367652
# short_model_Frtlner: 3.863340452880948e-06
# short_model_GCM: 0.00019835174953186652
# short_model_GEHL: 0.0006520698361782706
# short_model_GMC,: 3446.489178306005
# short_model_GMX: 0.00020743626373587176
# short_model_GRAND: -7.629895662830677e-05
# short_model_GULF: 0.0006096198014802212
# short_model_Genesis: -777.8347330845211
# short_model_Gx: 10895.34334789003
# short_model_HINO: 6924.057004735351
# short_model_HUMMER: 5277.978859680023
# short_model_Hino: 0.00030622545045844163
# short_model_Hobda: 0.00025715868241604767
# short_model_Hot: 13412.865983333193
# short_model_Hummer: 10966.264728305961
# short_model_IC: -11658.75253378031
# short_model_INTERNATIONAL: -0.0001477248006267473
# short_model_International: 4678.036488782319
# short_model_Isizu: -7153.206556703324
# short_model_Isuzu: 9836.99815858494
# short_model_JM1BK32F871604924: -3075.740473047705
# short_model_Janesville: 4.736223127110861e-05
# short_model_Jauguar: 9.510153722658288e-05
# short_model_Jayco: 0.00020220390433678403
# short_model_Kaiser: -4268.738261800097
# short_model_Lotus: 33427.026353015295
# short_model_MASERATI: 4096.971963863911
# short_model_MERCUTY: -9245.623264385013
# short_model_MERDECES: -0.0002284680540469708
# short_model_MGB: 6895.29773725779
# short_model_MITUSBISHI: -0.00017837099767348263
# short_model_MV-1: 1.8943977920571342e-05
# short_model_Maserati: 13354.272968890271
# short_model_Minin: 0.0001602786396688316
# short_model_Nascar: -3926.545559989624
# short_model_OLDSMOBILE: -0.00021875102538615465
# short_model_PLYMOUTH: 48653.75347548563
# short_model_PROGRAMS: -19528.64223037845
# short_model_Peterbilt: 57474.827793894015
# short_model_Pierce: 9096.541816368219
# short_model_Plymouth: 18809.805576154507
# short_model_QX: 3885.13730653646
# short_model_S60: -5356.553284868008
# short_model_SCION: -3533.3541716284935
# short_model_SL: 8684.12019105956
# short_model_Saab: -3561.841743907482
# short_model_Scion: -9368.941490539093
# short_model_Sea: 0.00035460035815049196
# short_model_Sterling: -6.369938091665972e-06
# short_model_Studebaker: -7051.260639486861
# short_model_Suzuki: -8388.684996483413
# short_model_THOMAS: -7885.604607818594
# short_model_Thomas: -3.816129992628703e-05
# short_model_Town: -4398.173799883545
# short_model_Triumph: 13916.21809403098
# short_model_Voltswagon: -8346.116342107844
# short_model_Xx: -30907.63834934413
# short_model_a-class: -4938.8239005961
# short_model_a3: -6864.2263279094705
# short_model_a3,: -4911.074254195242
# short_model_a4: -4237.150796058217
# short_model_a5: -104.45583220567931
# short_model_a6: -576.3846635436378
# short_model_a7: 4742.458415722853
# short_model_a8: -3049.2055975729104
# short_model_acadia: -6917.5569889397975
# short_model_accent: 140.55854597833226
# short_model_accord: -3639.392474167905
# short_model_all: -16133.153265166706
# short_model_allante: 5273.957136663751
# short_model_allroad: 412.83663389887613
# short_model_altima: -11858.41124465442
# short_model_am: 10919.523563971308
# short_model_amc: 292.88904811313967
# short_model_arcadia: -13991.279253943017
# short_model_armada: -2386.476366802254
# short_model_arteon: 11909.51995458607
# short_model_ascent: 15725.98595155165
# short_model_aspen: -0.0003720521526702214
# short_model_astra: -4185.037045558325
# short_model_astro: -5928.745004562209
# short_model_atlas: 7990.526168470697
# short_model_ats: -5107.374362300218
# short_model_aura: -926.4138209759994
# short_model_autobiography: 23134.724257888243
# short_model_avalanche: 1903.998432566344
# short_model_avalon: -4907.246710486477
# short_model_avanger: -9613.015951681245
# short_model_avenger: -9258.408432148886
# short_model_aveo: -9178.613944636676
# short_model_aviator: -5307.285343832957
# short_model_azera: -0.00018517510034143925
# short_model_aztek: -2100.3142111888806
# short_model_b-class: 0.00010640440541465068
# short_model_b-series: 4120.097327319457
# short_model_b2200: 9527.885538843695
# short_model_b2300: -2727.756063636788
# short_model_b2600i: -0.0001236959333255072
# short_model_baja: 9434.114371579859
# short_model_beetle: 1387.8870446447088
# short_model_bel: 16005.272700183958
# short_model_belair: 43264.157262923036
# short_model_benz: -2973.230583912644
# short_model_blackwood: -5.397345648816554e-05
# short_model_blazer: -1369.221397097448
# short_model_blue: -7781.0606840710725
# short_model_bolt: -3776.2399478005373
# short_model_bonanza: 0.0001524278380884425
# short_model_bonneville: -9516.42073664503
# short_model_boxster: -12131.557043156705
# short_model_bronco: 13659.622716559104
# short_model_brz: 8203.239643100018
# short_model_bug: 5792.714789574539
# short_model_bus: 14277.021225016311
# short_model_c: -10714.641605583625
# short_model_c-10: 24226.67840402593
# short_model_c-7500: -0.00013069998681203288
# short_model_c-class: -351.8184077491549
# short_model_c-hr: -15600.012766698288
# short_model_c-max: -13754.771454237261
# short_model_c/k: -5.67387087357929e-05
# short_model_c10: -131.83076964566496
# short_model_c250: -8562.062967544964
# short_model_c280: 7.036581246211426e-05
# short_model_c30: 0.00030331905054481467
# short_model_c300: -7421.650191239543
# short_model_c4500: 2552.0564413859934
# short_model_c5500: 1036.5652684090041
# short_model_c60: 7936.629251318348
# short_model_c6500: -4.758438626595307e-05
# short_model_c70: -678.6426040520969
# short_model_c8500: 14903.717884867487
# short_model_cabellero: 6.276569069996185e-05
# short_model_cabrio: 7351.485433730168
# short_model_caddilac: -10923.425846223128
# short_model_cadenza: 9203.437393966846
# short_model_caliber: -5465.442077631215
# short_model_camaro: 3818.717825935869
# short_model_camary: 2.7272897114016814e-05
# short_model_camero: -9103.721565108764
# short_model_camry: -6399.995116726052
# short_model_canyon: -2849.532989868081
# short_model_capri: 1.918219459184911e-05
# short_model_caprice: 595.1873883207928
# short_model_captiva: -7414.774410527871
# short_model_caravan: 55.696658034023116
# short_model_caravan/grand: -4410.086861092275
# short_model_cargo: -27731.664434434613
# short_model_cascada: -7406.30438596372
# short_model_cavalier: 3633.0890781023613
# short_model_cayenne: -14090.16423065272
# short_model_cayman: -334.73731787613644
# short_model_cc: 2839.942925570415
# short_model_cc300: -0.0003866317542815523
# short_model_cc4500: 18898.71521408876
# short_model_century: -4210.102284485146
# short_model_certified: 7996.511954227698
# short_model_challenger: 4574.827344293059
# short_model_charger: -2967.556127336541
# short_model_cherokee: -9768.287178335044
# short_model_chevelle: 31178.35417638046
# short_model_chevorlet: 5930.935475825297
# short_model_chryler: -6746.316895413869
# short_model_chysler: -5.8768779126694426e-05
# short_model_city: 0.0002610229785204865
# short_model_civic: -5826.733259603602
# short_model_cj-5: -6931.675896405462
# short_model_cj2a: -88.63825767867365
# short_model_cj5: 978.6778744495433
# short_model_cj7: 1959.0546280712513
# short_model_cj8: 1965.9483233544465
# short_model_cl-class: -3.796925102506066e-05
# short_model_cla: -5343.21632851379
# short_model_cla-class: -5393.897885416046
# short_model_clarity: -7113.198143911147
# short_model_classic: -4331.35728842465
# short_model_classuc: -0.00012444106505427044
# short_model_clk: -1473.4943507416726
# short_model_clk-class: -3544.9404926654806
# short_model_clk350: -4674.700424394824
# short_model_cls-class: 5667.561449463227
# short_model_cls550: -4747.660958977005
# short_model_clubman: -28606.514918415825
# short_model_cmax: -11555.533553933928
# short_model_cobalt: -8143.361801784979
# short_model_colbalt: -7296.55126363616
# short_model_colorado: -1081.0298766188257
# short_model_comet: 0.00011146202359668678
# short_model_commander: -7484.5479294701145
# short_model_compass: -14741.417925939253
# short_model_concorde: -676.3116649077066
# short_model_conquest: 12665.417537098987
# short_model_continental: 6713.595304587509
# short_model_convertible: -19442.802501208804
# short_model_cooper: -26073.214960663212
# short_model_corolla: -8289.49211592189
# short_model_corsair: 3524.6419368434717
# short_model_corvette: 12297.227494996318
# short_model_cougar: -7341.579570839217
# short_model_country: 45.995907000547255
# short_model_countryman: -17548.15317484368
# short_model_coupe: 6036.78011308869
# short_model_cr-v: -1742.658831225749
# short_model_crew: 8765.72192945436
# short_model_crossfire: 5375.629808355223
# short_model_crosstour: -510.8892876114177
# short_model_crosstrek: 2619.1197344793286
# short_model_crown: -9024.752824591658
# short_model_cruze: -11018.201297284895
# short_model_crv: -574.853748747681
# short_model_crz: -5155.706877649878
# short_model_ct: -12318.935026331272
# short_model_ct4: 868.8881923095713
# short_model_ct5: 2494.9562273985566
# short_model_ct6: 3529.6074636603885
# short_model_cts: -3369.947401561982
# short_model_cts-v: 10626.931623699802
# short_model_cts4: -7237.29365518812
# short_model_cube: -11754.08229989796
# short_model_cvr: 8.5680847405456e-05
# short_model_cx-3: -10888.071628165266
# short_model_cx-5: -6307.220728994866
# short_model_cx-7: -2778.5644992695543
# short_model_cx-9: -2174.1020621746225
# short_model_cx7: -4568.686075213388
# short_model_cx9: -8.042128320084885e-05
# short_model_d50: -5227.2914148854015
# short_model_dakota: -121.98571953948083
# short_model_dart: -8527.770404846742
# short_model_davidson: -3649.471531986486
# short_model_dealer*: 13858.995068962298
# short_model_defender: 33172.110759625684
# short_model_deisel: 510.6513275749198
# short_model_deluxe: 8787.261884244463
# short_model_denali: -4251.914542170954
# short_model_deville: -4856.831824627971
# short_model_diesel: -0.00011488744712551124
# short_model_discovery: 7966.945980171482
# short_model_dts: -6458.237422139936
# short_model_dump: 8911.418926449116
# short_model_duramax: -4362.225935070258
# short_model_durango: 1000.3253281180977
# short_model_durangon: 4949.9389668763415
# short_model_e: 3228.7764180825425
# short_model_e-150: 4278.952062590326
# short_model_e-250: -3746.7887545951144
# short_model_e-350: -1916.0799909840134
# short_model_e-450: 4840.812144718555
# short_model_e-class: 660.1069023336311
# short_model_e-golf: -1147.314562103289
# short_model_e-pace: 4518.085386464925
# short_model_e-series: -3214.3477919971065
# short_model_e150: 1515.802115423792
# short_model_e250: -6103.886787054177
# short_model_e320: 12438.386590349743
# short_model_e350: -3289.854858858483
# short_model_e450: -8779.867575520275
# short_model_e46: 27577.760099549367
# short_model_e500: -1791.1652139779549
# short_model_echo: -7095.0257301673655
# short_model_eclipse: 5886.160619166781
# short_model_econoline: -31.815301063050825
# short_model_ecosport: -8142.600988313131
# short_model_edge: -6277.716519317958
# short_model_el: 13974.22854996884
# short_model_elantra: 672.1859866738429
# short_model_elcamino: 5915.772318317548
# short_model_eldorado: -3773.39880386162
# short_model_element: -638.8795967185307
# short_model_enclave: -943.0157028026895
# short_model_encore: -10685.449572054273
# short_model_endeavor: 5052.661701228531
# short_model_envision: -7281.363813065144
# short_model_envoy: -5416.587291126257
# short_model_eos: 7237.019449200967
# short_model_eqinox: -752.2190032536646
# short_model_equinox: -6897.43382878046
# short_model_es: -8823.259994657024
# short_model_es300: -8.519092898495728e-05
# short_model_es330: -5099.058702312385
# short_model_es350: -7800.463888204368
# short_model_escalade: 5986.632323827662
# short_model_escape: -9655.398204548108
# short_model_escape-se,: -10489.586764162452
# short_model_escort: -5300.94620236232
# short_model_eurovan: 36080.4703982289
# short_model_evoque: -3941.564919152469
# short_model_excursion: 6672.231842674588
# short_model_expedition: -235.58821089157743
# short_model_explorer: -3426.3158229101073
# short_model_express: 3356.4305458966182
# short_model_f: 2596.9043877430204
# short_model_f-100: -3272.2468180828055
# short_model_f-150: 1478.5108852138153
# short_model_f-250: 6385.483547379807
# short_model_f-250sd: 10799.551455628616
# short_model_f-350: 5781.091516923371
# short_model_f-350sd: 19353.07018412448
# short_model_f-450: 1134.2367780788563
# short_model_f-450sd: 17745.423844646284
# short_model_f-550: 2095.4271375279873
# short_model_f-650: -3.738000674425927
# short_model_f-750: 6221.997957922029
# short_model_f-pace: 5910.628422534283
# short_model_f-type: 7220.56429344563
# short_model_f1: 172.2921371021262
# short_model_f100: 2.568781110312557e-05
# short_model_f150: 1787.9430442238208
# short_model_f250: 5595.682219433445
# short_model_f350: 4044.083074284733
# short_model_f450: 6172.514382753734
# short_model_f450sd: -1.1342957805027254e-05
# short_model_f50: -0.00011983463627984747
# short_model_f550: 11706.352824646336
# short_model_f600: 3782.2314959921146
# short_model_f650: 15738.794937951816
# short_model_f700: 5957.531440627104
# short_model_f750: 12726.654114419864
# short_model_falcon: 1.6002935808501206e-05
# short_model_fe: -8.401375271205325e-05
# short_model_fiero: -3112.583786533184
# short_model_fiesta: -13820.386264244147
# short_model_firebird: 3252.3507763228968
# short_model_fit: -9917.51422217264
# short_model_five: -7561.6033005823465
# short_model_fj: 9775.830188601672
# short_model_fj40: 13931.870896678804
# short_model_fleetmaster: 7931.050259602569
# short_model_fleetwood: -0.00035077543816441903
# short_model_flex: -6511.860807189728
# short_model_focus: -12523.354047470653
# short_model_fords: -4818.471296258032
# short_model_forester: 4976.539217804417
# short_model_forte: 218.3286357218808
# short_model_forte5: -50.927983547764
# short_model_foxbody: -2105.9601410185824
# short_model_freestar: -9163.846847578849
# short_model_freestyle: -5532.810020591687
# short_model_freightliner: 16165.235047743614
# short_model_frontier: -4787.466661429489
# short_model_fusion: -11936.083748796189
# short_model_fuso: 8038.957224378384
# short_model_fx35: 2641.0810874937447
# short_model_fx45: 1087.1158120951952
# short_model_g: 3844.746236003253
# short_model_g-class: 2.4289813154609874e-05
# short_model_g.: -10947.783198007088
# short_model_g20: 0.00010001605005527381
# short_model_g30: 813.0915563019482
# short_model_g35: 4902.8532318386515
# short_model_g35x: 3363.1435647943285
# short_model_g37: 2694.805097120314
# short_model_g37s: -187.47184351433356
# short_model_g37x: -0.00018481232130795888
# short_model_g4500: 930.2792347779138
# short_model_g5: -11007.881904951288
# short_model_g6: -9091.408494064844
# short_model_g8: 196.1413210553807
# short_model_galant: 2656.8232030877307
# short_model_genesis: 7068.865338575317
# short_model_ghia: 18358.973533610653
# short_model_gl: -12584.958205334564
# short_model_gl-class: -717.5999060379338
# short_model_gl450: 6.386571931216167e-05
# short_model_gla: -4012.248998382417
# short_model_gla-class: 5365.820529986786
# short_model_gladiator: 7543.050759973841
# short_model_glc: -793.5836734722814
# short_model_glc-class: 4496.878697138035
# short_model_gle: 3702.7840497303246
# short_model_gle-class: 8.107051507977303e-05
# short_model_glk: -4843.979766830976
# short_model_glk-class: -3260.0814884147326
# short_model_glk350: -3.772225886677916e-05
# short_model_gls: 9094.437451256199
# short_model_gmc/chev: 1346.118963793858
# short_model_gmce: 1191.4994200639553
# short_model_gmt-400: 2392.993124078507
# short_model_golf: 5413.304650662525
# short_model_gr: 0.00015656092705285118
# short_model_grand: -6468.5888822050165
# short_model_grandville: 9619.542384871096
# short_model_grumman: 3399.9129281981277
# short_model_gs: -4567.635935293857
# short_model_gs350: -0.00010683011441869894
# short_model_gs430: 6.0538390243891627e-05
# short_model_gt: 8981.1186614543
# short_model_gt-r: 28081.116343146863
# short_model_gti: 3425.625967548917
# short_model_gto: 10691.60572319035
# short_model_gx: 744.3783396633698
# short_model_gx460: 4.04814104513207e-05
# short_model_gx470: -4.952925519319251e-05
# short_model_hardbody: 1483.6375384729809
# short_model_hardtop: -24885.38761088979
# short_model_hearse: 4442.380288128392
# short_model_hhr: -6712.655133650813
# short_model_hiace: 1551.170464028638
# short_model_high: 5961.635331242519
# short_model_highlander: 170.03348592016658
# short_model_hr-v: -10115.06317144822
# short_model_hse: -2185.76746299086
# short_model_hummer: 9994.324145937195
# short_model_hyndai: -7390.598146397633
# short_model_i-miev: 9.505524280939426e-05
# short_model_i3: -15598.90581595219
# short_model_i30: -3.1904892921374994e-05
# short_model_i35: 3096.6861936729574
# short_model_ilx: -3075.8110546554417
# short_model_impala: -7888.1378034541185
# short_model_impreza: 4856.393316018481
# short_model_insight: -9401.146659942613
# short_model_international: -2656.571879844122
# short_model_ion: -3166.1783647072066
# short_model_ioniq: 3094.2256026140785
# short_model_is: -7920.538339050233
# short_model_is250: -16275.353827911376
# short_model_is300: -4416.3679140636605
# short_model_isf: 8268.31347309538
# short_model_isuzu: 3733.824977960313
# short_model_jeepster: -123.60812383599385
# short_model_jetta: -136.43856450808966
# short_model_jimmy: 7.200665277196094e-05
# short_model_jouney: -8736.510889065179
# short_model_journey: -7460.809121325756
# short_model_juke: -12495.941754913349
# short_model_jx35: -5.0429149723640876e-05
# short_model_k10: 9690.417952324122
# short_model_k20: -4.17286173615139e-05
# short_model_k30: 20516.55594880277
# short_model_k5: 1765.5333206469847
# short_model_k900: 9059.929966638192
# short_model_kicks: -12264.500846719933
# short_model_kodiak: -1978.040084241369
# short_model_l: 2888.3130794681933
# short_model_l300: 0.0001200377964778454
# short_model_lacrosse: -4309.522253565847
# short_model_lancer: 3847.8308438843032
# short_model_land: 15358.893077483292
# short_model_landcruiser: -1.8326065173823736e-05
# short_model_leaf: -14191.605187866422
# short_model_legacy: 3377.7566006693955
# short_model_legend: 5071.722955883505
# short_model_lemans: 21593.058416467073
# short_model_lesabre: -1995.689974404432
# short_model_liberty: -11452.536106338763
# short_model_lifted: 9710.560691459825
# short_model_lightning: 9.110058499572915e-06
# short_model_limousine: 1942.5429729310722
# short_model_long: -8652.21249775805
# short_model_lr2: -5674.5470183478965
# short_model_lr3: -2264.8209175237757
# short_model_lr4: -3255.0751050469107
# short_model_ls: -1730.797385987834
# short_model_ltd: -4507.97427406068
# short_model_lucerne: -5165.037518654192
# short_model_lx: 6540.333803312961
# short_model_lx450: 18797.070704166046
# short_model_m: -1783.2744522183325
# short_model_m-class: -3542.600007969337
# short_model_m3: 8172.807326451919
# short_model_m35: 1767.3025168042286
# short_model_m35s: 2401.6991836550133
# short_model_m5: 0.00012172434799140319
# short_model_macan: 3.6997116694692522e-06
# short_model_magnum: -666.9629633072643
# short_model_malibu: -7752.804769280708
# short_model_mallinia: -718.742312147134
# short_model_marineer,premier: -9472.267903254602
# short_model_mariner: -13332.196663856597
# short_model_mark: -3981.9215405561413
# short_model_maserati: 6443.423904640168
# short_model_matrix: -5564.626460824996
# short_model_maxima: -8961.098345521252
# short_model_maximum: -5217.873926332721
# short_model_mazda2: -7559.628509342085
# short_model_mazda3: -6719.083757459743
# short_model_mazda5: -5286.231304528418
# short_model_mazda6: -5558.71134970741
# short_model_mazda6i: -4024.8540814184316
# short_model_md-x: -13973.437650791924
# short_model_mdx: 5461.228520166582
# short_model_mercades: -7.355476463999366e-05
# short_model_mercedes-amg: 12513.337585790305
# short_model_metris: -1589.601481843161
# short_model_mg: 6330.467301117663
# short_model_miata: 3339.8888153600083
# short_model_milan: -12791.633563476646
# short_model_mirage: -7412.633870384752
# short_model_mkc: -4477.621503045522
# short_model_mks: -6474.466426207747
# short_model_mkt: -3300.0812125321613
# short_model_mkx: -1999.783024972468
# short_model_mkz: -6453.759658014366
# short_model_ml: -6159.23722631116
# short_model_ml350: -1516.8127806970708
# short_model_ml500: -0.0001766325965490978
# short_model_model: 741.2879656396634
# short_model_monte: 11727.687074993297
# short_model_montero: 5421.3255887417545
# short_model_mountaineer: -1054.2663888409013
# short_model_mpv: -4967.67664008312
# short_model_mr2: 2252.7944626278754
# short_model_murano: -8912.373866045511
# short_model_mustang: 45.316704759646484
# short_model_mx-5: -1109.07459702398
# short_model_nautilus: 3255.0636055575837
# short_model_navigator: 6737.507133726264
# short_model_neon: -4.573581892941547e-05
# short_model_new: 7019.8429724341895
# short_model_newport: 0.00028243277893125196
# short_model_niro: 2311.6296766137484
# short_model_nitro: -6516.7530067848
# short_model_nova: 16750.359469583014
# short_model_nv: -3704.8373262344576
# short_model_nv1500: -9.775276339496486e-05
# short_model_nv200: -10635.833150395816
# short_model_nv2500: -2348.567776094049
# short_model_nv2500hd: -6.029949895491882e-05
# short_model_nx: -7081.4145348612155
# short_model_nx300: -7019.100760410908
# short_model_oddyssey: -0.00016024424985516816
# short_model_odyssey: -2698.7015250202776
# short_model_oldsmobile: -1022.2535737403323
# short_model_optima: 2251.7185310397717
# short_model_optimia: 5368.154403628223
# short_model_other: 671.96500239367
# short_model_outback: 5161.242732880004
# short_model_outlander: 254.8508531106604
# short_model_outlook: 1676.1722779130678
# short_model_paceman: -26862.303606065863
# short_model_pacifica: 2551.2487033366947
# short_model_panamera: -3349.8019747676426
# short_model_panel: 4980.561075698482
# short_model_park: -2225.512936034982
# short_model_passat: 126.27695413029855
# short_model_passport: -766.1905189559158
# short_model_pathfinder: -8004.08372252608
# short_model_patriot: -16023.189847263311
# short_model_phaeton: 9441.071433587571
# short_model_pick: -4.200566763756797e-05
# short_model_pickup: 4288.035389017338
# short_model_pilot: -339.40976247863694
# short_model_plymouth: 12694.46746330969
# short_model_pontaic: -0.00026630742104316596
# short_model_prelude: 5620.73876731496
# short_model_prius: -7881.864438074719
# short_model_prizm: -1653.1061563158335
# short_model_promaster: -5626.332202900504
# short_model_protege: -2294.427944651602
# short_model_pt: 1287.206857419743
# short_model_putback: 8052.600596230346
# short_model_q3: -3689.3654760884947
# short_model_q5: -751.5756219864401
# short_model_q50: 1629.3981913362068
# short_model_q60: 9518.363628915693
# short_model_q7: -729.7487104860986
# short_model_q70: 3257.119452068252
# short_model_quattro: -5088.893304271678
# short_model_quest: -6978.894217564064
# short_model_qx50: 106.68817070915904
# short_model_qx56: 252.85418002957226
# short_model_qx60: 4512.0014929920135
# short_model_qx70: 2406.604498412834
# short_model_qx80: 16121.363580250927
# short_model_r-class: -8049.28954206872
# short_model_r32: 10291.49322511831
# short_model_rabbit: 5657.216826844243
# short_model_rainier: -7519.640716369132
# short_model_ram1500: 2527.7854840819273
# short_model_ram2500: 4492.496155903701
# short_model_ramcharger: -2871.087249967679
# short_model_range: 9063.12310864352
# short_model_ranger: -3666.0101359862324
# short_model_rat: 7726.785236291957
# short_model_rav: -5147.570732656237
# short_model_rav4: -5311.948297671138
# short_model_rc: -5865.743759735265
# short_model_rdx: 2566.2476768700635
# short_model_reatta: -3058.840503061291
# short_model_rebel: 12163.4985640054
# short_model_regal: -6376.101818456917
# short_model_rendezvous: -11505.862818236601
# short_model_renegade: -14056.624120061671
# short_model_replica: -1.3723474694415927e-06
# short_model_ridgeline: 3036.0505063659366
# short_model_rio: -665.4776297471507
# short_model_rivera: 3779.8320596873805
# short_model_riviera: 2133.8310933534353
# short_model_rl: 2168.9252601347594
# short_model_rlx: 366.42614102988796
# short_model_roadmaster: -4.708390724772471e-05
# short_model_roadster: -29245.704965473513
# short_model_rogue: -10319.954662807559
# short_model_romeo: -578.9046644976224
# short_model_rondo: -6.19960910626105e-05
# short_model_rouge: -10310.858640862334
# short_model_routan: -153.51188643322126
# short_model_rs: -9.371295800519874e-05
# short_model_rsx: -964.7403726182159
# short_model_rx: -4515.455991505139
# short_model_rx-8: -2629.9694870626995
# short_model_rx300: -6429.839921543553
# short_model_rx330: -6871.194900244406
# short_model_rx350: -13776.256853640662
# short_model_rx400h: -5326.341862333165
# short_model_rx7: 661.3100049667429
# short_model_rx8: -3744.6250295499767
# short_model_s: 17875.23791498571
# short_model_s-10: 2.582096340120188e-05
# short_model_s-class: 1623.2945017489917
# short_model_s/w: 9.874185707303695e-05
# short_model_s10: 934.1723843658983
# short_model_s2000: 17037.423138877093
# short_model_s3: -9272.09828096357
# short_model_s320: 6487.127271650425
# short_model_s4: 3403.487415956058
# short_model_s40: -5020.508619438624
# short_model_s430: -5067.644952645579
# short_model_s5: 9056.006458289983
# short_model_s500: -4899.827731477708
# short_model_s6: 7668.5411830071835
# short_model_s60: -5152.701502742123
# short_model_s7: -7246.417178191744
# short_model_s70: 1430.398667592369
# short_model_s8: 17779.250157583338
# short_model_s90: -534.5583388293246
# short_model_saab: -6381.265773303047
# short_model_sable: -6021.190994847328
# short_model_santa: 6560.602616230592
# short_model_sante: 0.00012934781807416584
# short_model_savana: -2409.044900582097
# short_model_sc: -2135.6080529114724
# short_model_sc2: -1801.7500249657755
# short_model_sc300: -826.5569686116643
# short_model_school: -7290.583836257958
# short_model_scion: -8051.397744289231
# short_model_sebring: 2147.3156135470344
# short_model_sedan: 1413.3365656509834
# short_model_sedona: 3122.7351158021397
# short_model_seirra: 1788.8831053798915
# short_model_sentra: -14505.525768591486
# short_model_sequioa: 2.7317646527080797e-05
# short_model_sequoia: 2396.75257070301
# short_model_seville: 446.4015990587281
# short_model_shelby: -0.00010882120659516659
# short_model_sienna: -1300.286150814962
# short_model_sierra: 3023.0059871006742
# short_model_sierra1500: 4.743662520922953e-05
# short_model_silverado: 6395.271524067504
# short_model_sky: 4174.257176645009
# short_model_skylark: -3716.636276004358
# short_model_sl-class: 9574.71766202585
# short_model_sl2: -808.9658805637313
# short_model_sl500: -6.476532371380017e-05
# short_model_sl55: 6120.16468483433
# short_model_sl550: 2993.7603116958894
# short_model_slc: 8510.710562493154
# short_model_sle: 4058.895605305867
# short_model_slk: -1100.4469724900382
# short_model_slk-class: -143.29414300475005
# short_model_slt: -4179.371794239735
# short_model_smart: -15072.868367524552
# short_model_solara: -4192.665401984827
# short_model_solstice: -8.143536979332566e-05
# short_model_sonata: 2110.6601888179
# short_model_sonic: -12361.258735497528
# short_model_sonoma: -37.24291826515981
# short_model_sorento: 6155.757100328336
# short_model_sorrento: -8.818994501780253e-06
# short_model_soul: 1201.2314074803708
# short_model_soul+: 1775.9313396936423
# short_model_spark: -15230.540012911797
# short_model_spectra: 6539.174539048613
# short_model_sport: 7789.142497428328
# short_model_sportage: 2697.6495581219533
# short_model_sprinter: 2463.1159860675175
# short_model_srx: -4143.829434098154
# short_model_srx-v6: -4381.901644131
# short_model_srx4: -3186.1388609339338
# short_model_srx~awesome: -8865.461925665095
# short_model_ss: 11465.058383033698
# short_model_ssr: 8671.359305013208
# short_model_starcraft: -19458.23831706332
# short_model_step-van: -7.195456623776408e-05
# short_model_stinger: 14346.882091118838
# short_model_stratus: -4908.173187243541
# short_model_sts: -7314.571982116118
# short_model_studebaker: -2989.1571137279957
# short_model_suburban: 4334.73773455397
# short_model_super: 9074.314866365492
# short_model_supra: 4.2930048493872164e-05
# short_model_suv: -5343.079715495683
# short_model_suzuki: -5909.891303416583
# short_model_svx: 15460.098837256517
# short_model_t: -8470.322727691282
# short_model_t-350: -493.6713255508451
# short_model_t-bucket: 5468.455718765374
# short_model_tacoma: 3718.081853606655
# short_model_tahoe: 4261.077570249956
# short_model_tarsus: -8147.214381909636
# short_model_taurus: -8372.99540735934
# short_model_tc5500: 28543.15220613207
# short_model_telluride: 17952.966375911776
# short_model_tercel: -1751.6841929916393
# short_model_terrain: -9893.475569426888
# short_model_thing: 18059.14267656793
# short_model_thomas: -6492.532488213906
# short_model_thrift: -2581.7328124874516
# short_model_thunderbird: 15878.497066023783
# short_model_tiguan: 1949.2489421912921
# short_model_titan: -2328.8964959970785
# short_model_tl: -336.02653089732297
# short_model_tlx: 2104.141616119566
# short_model_torrent: -10977.74174521438
# short_model_touareg: 6337.182849234622
# short_model_town: 914.291063867807
# short_model_tracker: -5231.233169342315
# short_model_tractor: -1237.4501155453922
# short_model_trailblazer: -2365.7464096798544
# short_model_trans: -6.550343823619187e-05
# short_model_transit: -3718.855984469772
# short_model_traverse: -2994.1890958930608
# short_model_trax: -12409.713431951614
# short_model_tribeca: 6838.259797786666
# short_model_tribute: -5989.743563450896
# short_model_triumph: -4368.9494209167215
# short_model_truck: -446.59314231066963
# short_model_tsx: -89.78113565817294
# short_model_tt: 3712.312590714098
# short_model_tucson: 5547.675675930031
# short_model_tudor: 35620.67834841097
# short_model_tundra: 6459.048685630059
# short_model_uplander: -0.00013197787302487995
# short_model_utility: 3.16554414894199e-05
# short_model_ux: -7497.811834586823
# short_model_v50: -8386.845363562468
# short_model_v6: 24101.920468181237
# short_model_v60: -33042.54138992186
# short_model_v90: -29591.17831458692
# short_model_van: 3004.102655254108
# short_model_vanagon: 15839.7440446086
# short_model_vandura: 6016.797644107863
# short_model_velar: 19702.19245841501
# short_model_veloster: 3760.4734792642957
# short_model_venture: -527.8119512493973
# short_model_venza: -2056.6531931479894
# short_model_veracruz: 7170.664846608105
# short_model_verano: -11906.427778740412
# short_model_versa: -16755.972914927723
# short_model_vibe: -7878.545460460775
# short_model_villager: -6688.531590424291
# short_model_vnl: 4776.223692200306
# short_model_volt: -11224.92299569478
# short_model_voyager: 1545.8901365263036
# short_model_vtx1300c: -11081.472173803028
# short_model_vue: -2222.2658257265057
# short_model_w350: 9958.981984435974
# short_model_willys: 7550.283874678746
# short_model_windstar: -366.9416223118961
# short_model_wrangler: -660.3013441826329
# short_model_wrx: 7686.861370222813
# short_model_x-3: -5.610786433862813e-05
# short_model_x-type: -3784.4584826261553
# short_model_x1: -8005.479223825571
# short_model_x2: -1643.9560863511188
# short_model_x3: -3528.315852212569
# short_model_x4: -1142.2019016417387
# short_model_x5: -3593.9656926911616
# short_model_x6: 8302.396567772754
# short_model_xc: -7892.499780747589
# short_model_xc40: -28748.278020259353
# short_model_xc60: -3726.3470006570656
# short_model_xc70: -2660.9661302855125
# short_model_xc90: 1517.4941979641299
# short_model_xe: -7047.0548651914205
# short_model_xf: -1655.6259351010456
# short_model_xj: -8099.480623032039
# short_model_xj-series: 7750.8766452977015
# short_model_xj8: -1711.372659124023
# short_model_xk8: -1303.8248384810909
# short_model_xt4: 1930.4952554528077
# short_model_xt5: 4434.639356215767
# short_model_xt6: 21164.044974583194
# short_model_xterra: -3715.0901835896875
# short_model_xts: -4303.1385643156855
# short_model_xv: 5489.781356398617
# short_model_yaris: -8696.483026399483
# short_model_yukon: 323.3021078961855
# short_model_z: -4024.209407530574
# short_model_z3: -1430.9456238005987
# short_model_z4: 5973.456108530803
# short_model_zephyr: -8.337038161698729e-05
# short_model_zx2: -7379.282047129008
# transmission_automatic: -457.7696235076679
# transmission_manual: 781.9945068907739
# transmission_other: -324.22037654261203
# region_SF bay area: -1234.8572258128343
# region_abilene: 6494.335917071258
# region_akron / canton: -451.2177604860495
# region_albany: -1040.5018751157636
# region_albuquerque: 1344.2279459761671
# region_altoona-johnstown: -135.02881109120466
# region_amarillo: -3628.232946045356
# region_ames: 3695.2418838519147
# region_anchorage / mat-su: 333.44166590574343
# region_ann arbor: 233.80287012265077
# manufacturer_other: -688.9214996665663
# manufacturer_pontiac: 2290.6933120046324
# manufacturer_porsche: 19203.572820282636
# manufacturer_ram: 3662.564709538787
# manufacturer_rover: 1760.2388182294942
# manufacturer_saturn: -4371.869624664413
# manufacturer_subaru: -9700.082574830487
# manufacturer_tesla: 10472.417156787933
# manufacturer_toyota: 471.4971691128115
# manufacturer_volkswagen: -9564.273596932031
# manufacturer_volvo: 777.6174193408133
# state_ak: -4704.0777501391
# state_al: 259.61661303746916
# state_ar: -3455.879808134387
# state_az: 1982.5654281643228
# state_ca: -1168.0225177565694
# state_co: -1558.2160356575564
# state_ct: 26.011440396314185
# state_dc: -182.81500822499453
# state_de: -188.0873677759706
# state_fl: 2808.9408272393184
# state_ga: 1864.737441607901
# state_hi: -640.8676297012546
# state_ia: -2805.6549042999973
# state_id: -1460.6451284169568
# state_il: -126.20219381242173
# state_in: 1350.1156221775836
# state_ks: 962.15625678685
# state_ky: 314.9065229558229
# state_la: 5431.69205808403
# state_ma: -318.3555056246448
# state_md: 995.3148842108756
# state_me: -96.71281113294248
# state_mi: -1727.2667116635678
# state_mn: -354.2088026769105
# state_mo: 1068.5215985987627
# state_ms: -1204.5254124757464
# state_mt: -35.88928954587033
# state_nc: 437.48641135244486
# state_nd: -2135.4466053391707
# state_ne: 2965.4296417094592
# state_nh: -459.3962029362302
# state_nj: -714.1783460604385
# state_nm: -1684.3579214070496
# state_nv: 1637.4679656499443
# state_ny: 935.1443151586911
# state_oh: -289.186100404795
# state_ok: 413.8913200442569
# state_or: -1468.8772078384457
# state_pa: -346.17228050639255
# state_ri: 393.3213164963128
# state_sc: 1419.054739816888
# state_sd: 1783.0457964288578
# state_tn: -692.4697851282531
# state_tx: 2050.5838768801586
# state_ut: 1676.9394399298897
# state_va: -329.2991673443288
# state_vt: 86.07624660027153
# state_wa: 299.93619143562427
# state_wi: -1017.8044772671245
# state_wv: -2602.1878165146613
# state_wy: 603.8446352585347
# title_status_clean: 1602.168427842934
# title_status_lien: 654.3973417080039
# title_status_missing: -2675.1128668779734
# title_status_parts only: 5199.104168198797
# title_status_rebuilt: -2175.44528901783
# title_status_salvage: -2605.111739245857
# age_category_average: -1601.9753321597473
# age_category_new: 1177.410453772733
# age_category_old: 424.56904356315704
# lat_std: 943.3228892724674
# long_std: -801.7603954470851
# year_std: 2803.982118030128
# desc_len_std: 578.163571874994
# model_in_desc_std: 191.51210712268107
# model_len_std: 25.18226866435407
# model_word_count_std: 643.9505175555123
# month_std: -166.69160529098076
# dayofweek_std: 23.050436855193993
# diff_years_std: -2803.9792180349195
#
# Фичи с нулевыми коэффициентами:
# Index(['manufacturer_ferrari'], dtype='object')
#
# MAE после удаления фичей с нулевыми коэффициентами: 4600.341120992148

# %% [markdown]
# **Задача 1. Логистическая регрессия**
#
# Теперь в рамках тех же данных попробуйте предсказать `price_category` с помощью алгоритма логистической регрессии. Предварительно из датафрейма удалите переменные, в которых косвенно содержится информация о целевой переменной (`odometer/price_std`, `price`).
#
# Для обученной модели нужно:
#
# - рассчитать и вывести метрику качества (accuracy) на тренировочной выборке;
# - сделать предикт на тестовых данных и положить его в переменную `logreg_pred`;
# - рассчитать и вывести accuracy и confusion_matrix на тестовой выборке.
#
#
# Задание засчитывается, если:
# - accuracy на тренировочной выборке > 87%;
# - accuracy на тестовой выборке > 75.5%.
#
# Для улучшения метрики можно преобразовывать входные данные, тюнить параметры логистической регрессии.

# %%
from sklearn.preprocessing import StandardScaler
df_prepared = df.drop(columns=['odometer/price_std', 'price_category', 'id'])
X = df.drop(columns=['price_category'])
y = df['price_category']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


logreg_model = LogisticRegression(random_state=42, solver='liblinear', penalty='l1', C=0.5)  
logreg_model.fit(X_train, y_train)

train_pred = logreg_model.predict(X_train)
train_accuracy = accuracy_score(y_train, train_pred)
print(f'Accuracy на тренировочной выборке: {train_accuracy}')


logreg_pred = logreg_model.predict(X_test)


test_accuracy = accuracy_score(y_test, logreg_pred)
print(f'Accuracy на тестовой выборке: {test_accuracy}')

conf_matrix = confusion_matrix(y_test, logreg_pred)
print(f'Confusion Matrix:\n{conf_matrix}')
#Добавил удаление 'id'
# Out:
# Accuracy на тренировочной выборке: 0.9936135452250111
# Accuracy на тестовой выборке: 0.9674289674289674
# Confusion Matrix:
# [[979   0  18]
#  [  0 925  28]
#  [ 20  28 888]]

# %% [markdown]
# **Задача 2. Многослойный персептрон**
#
# Решите задачу, поставленную в предыдущем задании, применив модель многослойного персептрона. Добейтесь лучших значений точности на тренировочной и тестовой выборках, чем на логистической регрессии, с помощью данного алгоритма.
#
# Значимым увеличением точности в данном задании будем считать увеличение больше, чем на 0.01 по метрике accuracy.

# %%
df_prepared = df
X = df_prepared.drop(columns=['price_category'])
y = df_prepared['price_category']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


mlp_model = MLPClassifier(hidden_layer_sizes=(256, 128, 64),  
                            activation='relu',      
                            solver='adam',           
                            alpha=0.0001,         
                            batch_size='auto',
                            learning_rate='adaptive',
                            max_iter=300,           
                            random_state=42)         
mlp_model.fit(X_train, y_train)

train_pred = mlp_model.predict(X_train)
train_accuracy = accuracy_score(y_train, train_pred)
print(f'Accuracy на тренировочной выборке: {train_accuracy}')

mlp_pred = mlp_model.predict(X_test)

test_accuracy = accuracy_score(y_test, mlp_pred)
print(f'Accuracy на тестовой выборке: {test_accuracy}')

conf_matrix = confusion_matrix(y_test, mlp_pred)
print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Accuracy на тренировочной выборке: 0.9961384226941927
# Accuracy на тестовой выборке: 0.8416493416493417
# Confusion Matrix:
# [[836   5 156]
#  [  2 848 103]
#  [ 61 130 745]]

# %% [markdown]
# **Задача 3. Сравнение с древовидными моделями**
#
# Обучите модель случайного леса на тех же данных для предсказания `price_category`. Сравните качество с моделью логистической регрессии и многослойного персептрона. Словами опишите, какая из моделей в каких случаях работает лучше по результатам на тестовой выборке, и обоснуйте свой выбор.

# %%
from sklearn.ensemble import RandomForestClassifier

X = df_prepared.drop(columns=['price_category'])
y = df_prepared['price_category']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42) 
rf_model.fit(X_train, y_train)  
rf_pred = rf_model.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_pred)
print(f'Random Forest Accuracy: {rf_accuracy}')
#Н у пока что случайный лес работает лучше всех на тестовой выборке, ну по самому простой метрике - аккураси(просто я ещё узнал про рекол и пресижен)
# Out:
# Random Forest Accuracy: 0.9809424809424809

# %% [markdown]
# **Задача 4. Стратегия голосования**
#
# Реализуйте стратегию голосования для предсказания целевой переменной.
# Голосование в задаче классификации — это когда несколько моделей выдают свои предикты, и финальным выбирается тот предикт, который предсказали большинство моделей.
#
# Для реализации этой стратегии проделайте следующее:
#
# - сохраните предсказания каждой из моделей (случайный лес, многослойный персептрон, логистическая регрессия) для тестовой выборки в датафрейм `pred_df`;
# - в четвертую колонку `target` положите тот класс, который предсказало большинство классификаторов. Например, если в строке были значения `high, medium, medium`, в `target` нужно положить `medium`.
#
#      Если в строке три разных класса — `high, medium, low`, — придумайте свою стратегию по выбору значения. Самая простая стратегия: выбрать рандомно одно значение из трёх.
#
# - посчитайте точность предсказания с помощью голосования. Выведите значения метрик accuracy и confusion_matrix.
#
#
# Добейтесь значения точности > 78%

# %%
import random
df_prepared = df.drop(columns=['odometer/price_std', 'price', 'id'])

X = df_prepared.drop(columns=['price_category'])
y = df_prepared['price_category']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

logreg_model = LogisticRegression(random_state=42, solver='liblinear', penalty='l1', C=0.5)
logreg_model.fit(X_train_scaled, y_train)
logreg_pred = logreg_model.predict(X_test_scaled)


mlp_model = MLPClassifier(hidden_layer_sizes=(256, 128, 64), activation='relu', solver='adam',
                           alpha=0.0001, max_iter=300, random_state=42)
mlp_model.fit(X_train_scaled, y_train)
mlp_pred = mlp_model.predict(X_test_scaled)


rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)


pred_df = pd.DataFrame({
    'logreg': logreg_pred,
    'mlp': mlp_pred,
    'rf': rf_pred
})


def voting_strategy(row):

    counts = row.value_counts()
    if len(counts) == 3:
        return random.choice(row.tolist())
    else:
        return counts.index[0]

pred_df['target'] = pred_df.apply(voting_strategy, axis=1)


voting_accuracy = accuracy_score(y_test, pred_df['target'])
conf_matrix_voting = confusion_matrix(y_test, pred_df['target'])

print(f'Voting Accuracy: {voting_accuracy}')
print(f'Confusion Matrix (Voting):\n{conf_matrix_voting}')
# Out:
# Voting Accuracy: 0.7688842688842689
# Confusion Matrix (Voting):
# [[834  30 133]
#  [ 19 793 141]
#  [170 174 592]]

# %% [markdown]
# **Примечание:**
#
# В этом домашнем задании в задаче номер 1 и далее перед вами встал выбор: включать ли в обучение колонку `id`. При удалении данной колонки во время обучении логистической регрессии качество заметно улучшается.
#
# Вообще обучать любую модель (будь то логистическая или линейная регрессия, или древовидный алгоритм) на данных айдишников не считается хорошей практикой. Как правило, между `id` и целевой переменной не должно быть никаких взаимосвязей. Включая колонку `id` в качества атрибута в обучение, вы стараетесь "заточить" результаты своей модели под айдишники записей. Таким образом модель обучится на некотором наборе "частных случаев", и, возможно, не обратит внимание на общие зависимости.
